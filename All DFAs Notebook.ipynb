# %%
from graphviz import Digraph

gra = Digraph()

#initial state
gra.node('s','',color='white')
gra.node('s0', 's0',shape='circle')
gra.edge('s','s0')

#states for words starting with 'a'
gra.node('s1', 's1',shape='circle')
gra.node('s2', 's2',shape='circle')
gra.node('s3','s3',shape='doublecircle')
gra.node('s4', 's4',shape='circle')
gra.node('s5', 's5',shape='circle')
gra.node('s6', 's6',shape='circle')
gra.node('s7','s7',shape='doublecircle')

#reject States
gra.node('r', 'Reject',shape='circle')
gra.node('r1', 'Reject',shape='circle')
gra.node('r2', 'Reject',shape='circle')
gra.node('r3', 'Reject',shape='circle')
gra.node('r4', 'Reject',shape='circle')
gra.node('r5', 'Reject',shape='circle')
gra.node('r6', 'Reject',shape='circle')
gra.node('r7', 'Reject',shape='circle')
gra.node('r8', 'Reject',shape='circle')
gra.node('r9', 'Reject',shape='circle')
gra.node('r10', 'Reject',shape='circle')
gra.node('r11', 'Reject',shape='circle')
gra.node('r12', 'Reject',shape='circle')
gra.node('r13', 'Reject',shape='circle')
gra.node('r14', 'Reject',shape='circle')
gra.node('r15', 'Reject',shape='circle')
gra.node('r16', 'Reject',shape='circle')
gra.node('r17', 'Reject',shape='circle')
gra.node('r18', 'Reject',shape='circle')
gra.node('r19', 'Reject',shape='circle')
gra.node('r20', 'Reject',shape='circle')
gra.node('r21', 'Reject',shape='circle')

#edge of first letter 'a'
gra.edge('s0','s1','a|A')

#"and" edges
gra.edge('s1','s2','n|N')
gra.edge('s2','s3','d|D')

#"array" edges
gra.edge('s1','s4','r|R')
gra.edge('s4','s5','r|R')
gra.edge('s5','s6','a|A')
gra.edge('s6','s7','y|Y')

#reject edges for words starting with 'a'
gra.edge('s1','r','[a-m]|[A-M]|[o-q]|[O-Q]|[s-z]|[S-Z]')
gra.edge('s2','r','[a-c]|[A-c]|[e-z]|[E-Z]')
gra.edge('s3','r','[a-z]|[A-Z]')
gra.edge('s4','r1','[a-q]|[A-Q]|[s-z]|[S-Z]')
gra.edge('s5','r1','[b-z]|[B-Z]')
gra.edge('s6','r1','[a-x]|[A-X]|z|Z')
gra.edge('s7','r1','[a-z]|[A-Z]')
gra.edge('r1','r1','[a-z]|[A-Z]')

#states for words starting with 'b'
gra.node('s8', 's8',shape='circle')
gra.node('s9', 's9',shape='circle')
gra.node('s10', 's10',shape='circle')
gra.node('s11', 's11',shape='circle')
gra.node('s12','s12',shape='doublecircle')

#edge for start letter 'b'
gra.edge('s0','s8','b|B')

#"begin" edges
gra.edge('s8','s9','e|E')
gra.edge('s9','s10','g|G')
gra.edge('s10','s11','i|I')
gra.edge('s11','s12','n|N')

#reject edges for words starting with 'b'
gra.edge('s8','r2','[a-d]|[A-D]|[f-z]|[F-Z]')
gra.edge('s9','r2','[a-f]|[A-F]|[h-z]|[H-Z]')
gra.edge('s10','r2','[a-h]|[A-H]|[j-z]|[J-Z]')
gra.edge('s11','r2','[a-m]|[A-M]|[o-z]|[O-Z]')
gra.edge('s12','r2','[a-z]|[A-Z]')
gra.edge('r2','r2','[a-z]|[A-Z]')

#node for start letter 'c'
gra.node('s13', 's13',shape='circle')

#nodes for words starting with 'c'
gra.node('s14', 's14',shape='circle')
gra.node('s15', 's15',shape='circle')
gra.node('s16', 's16',shape='circle')
gra.node('s17', 's17',shape='circle')
gra.node('s18', 's18',shape='circle')
gra.node('s19', 's19',shape='doublecircle')

#edge for start letter 'c'
gra.edge('s0','s13','c|C')

#"case" edges
gra.edge('s13','s14','a|A')
gra.edge('s14','s15','s|S')
gra.edge('s15','s19','e|E')

#"const" edges
gra.edge('s13','s16','o|O')
gra.edge('s16','s17','n|N')
gra.edge('s17','s18','s|S')
gra.edge('s18','s19','T|t')

#reject edges for words starting with 'c'
gra.edge('s13','r3','[b-n]|[B-N]|[p-z]|[P-Z]')
gra.edge('s14','r3','[a-r]|[A-R]|[t-z]|[T-Z]')
gra.edge('s15','r3','[a-d]|[A-D]|[f-z]|[F-Z]')
gra.edge('r3','r3','[a-z]|[A-Z]')
gra.edge('s16','r4','[a-m]|[A-M]|[o-z]|[O-Z]')
gra.edge('s17','r4','[a-r]|[A-R]|[t-z]|[T-Z]')
gra.edge('s18','r4','[a-s]|[A-S]|[u-z]|[U-Z]')
gra.edge('s19','r4','[a-z]|[A-Z]')
gra.edge('r4','r4','[a-z]|[A-Z]')

#node for start letter 'd'
gra.node('s20', 's20',shape='circle')

#edge for start letter 'd'
gra.edge('s0','s20','d|D')

#nodes for words starting with 'd'
gra.node('s21', 's21',shape='circle')
gra.node('s22', 's22',shape='doublecircle')
gra.node('s23', 's23',shape='circle')
gra.node('s24', 's24',shape='circle')
gra.node('s25', 's25',shape='circle')
gra.node('s26', 's26',shape='doublecircle')

#"do" edges
gra.edge('s20','s22','o|O')

#"div" edges
gra.edge('s20','s21','i|I')
gra.edge('s21','s26','v|V')

#"downto" edges
gra.edge('s22','s23','w|W')
gra.edge('s23','s24','n|N')
gra.edge('s24','s25','t|T')
gra.edge('s25','s26','o|O')

#reject edges for words starting with 'd'
gra.edge('s20','r5','[a-h]|[A-H|[j-n]|[J-N]|[p-z]|[P-Z]')
gra.edge('s21','r5','[a-u]|[A-U]|[w-z]|[W-Z]')
gra.edge('s22','r5','[a-v]|[A-V]|[x-z]|[X-Z]')
gra.edge('s23','r5','[a-m]|[A-M]|[o-z]|[O-Z]')
gra.edge('s24','r5','[a-s]|[A-S]|[u-z]|[U-Z]')
gra.edge('s25','r5','[a-n]|[A-N]|[p-z]|[P-Z]')
gra.edge('r5','r5','[a-z]|[A-Z]')
gra.edge('s26','r5','[a-z]|[A-Z]')

#node for start letter 'e'
gra.node('s27', 's27',shape='circle')

#edge for start letter 'e'
gra.edge('s0','s27','e|E')

#nodes for words starting with 'e'
gra.node('s28', 's28',shape='circle')
gra.node('s29', 's29',shape='circle')
gra.node('s30', 's30',shape='circle')
gra.node('s31', 's31',shape='doublecircle')

#"else" edges
gra.edge('s27','s28','l|L')
gra.edge('s28','s29','s|S')
gra.edge('s29','s31','e|E')

#"end" edges
gra.edge('s27','s30','n|N')
gra.edge('s30','s31','d|D')

#reject edges for words starting with 'e'
gra.edge('s27','r6','[a-k]|[A-K]|m|M|[n-z]|[N-Z]')
gra.edge('s28','r6','[a-r]|[A-R]|[t-z]|[T-Z]')
gra.edge('s29','r6','[a-d]|[A-D]|[f-z]|[F-Z]')
gra.edge('s30','r6','[a-c]|[A-C]|[e-z]|[E-Z]')
gra.edge('r6','r6','[a-z]|[A-Z]')
gra.edge('s31','r6','[a-z]|[A-Z]')

#node for start letter 'f'
gra.node('s32', 's32',shape='circle')

#edge for start letter 'f'
gra.edge('s0','s32','f|F')

#nodes for words starting with 'F'
gra.node('s33', 's33',shape='circle')
gra.node('s34', 's34',shape='circle')
gra.node('s35', 's35',shape='circle')
gra.node('s36', 's36',shape='circle')
gra.node('s37', 's37',shape='circle')
gra.node('s38', 's38',shape='circle')
gra.node('s39', 's39',shape='circle')
gra.node('s40', 's40',shape='circle')
gra.node('s41', 's41',shape='circle')
gra.node('s42', 's42',shape='doublecircle')

#file edges
gra.edge('s32','s33','i|I')
gra.edge('s33','s34','l|L')
gra.edge('s34','s42','e|E')

#function edges
gra.edge('s32','s35','u|U')
gra.edge('s35','s36','n|N')
gra.edge('s36','s37','c|C')
gra.edge('s37','s38','t|T')
gra.edge('s38','s39','i|I')
gra.edge('s39','s40','o|O')
gra.edge('s40','s42','n|N')

#for edges
gra.edge('s32','s41','o|o')
gra.edge('s41','s42','r|R')

#reject edges for words starting with 'f'
gra.edge('s32','r7','[a-h]|[A-H|[j-n]|[J-N]|[p-t]|[P-T]|[v-z]|[V-Z]')
gra.edge('s33','r7','[a-h]|[A-H]|[j-z]|[J-Z]')
gra.edge('s34','r7','[a-d]|[A-d]|[f-z]|[F-Z]')
gra.edge('s35','r7','[a-m]|[A-M]|[o-z]|[O-Z]')
gra.edge('s36','r7','[a-b]|[A-B]|[d-z]|[D-Z]')
gra.edge('s37','r7','[a-s]|[A-S]|[u-z]|[U-Z]')
gra.edge('s38','r7','[a-h]|[A-H]|[j-z]|[J-Z]')
gra.edge('s39','r7','[a-n]|[A-N]|[p-z]|[P-Z]')
gra.edge('s40','r7','[a-m]|[A-M]|[o-z]|[O-Z]')
gra.edge('s41','r7','[a-q]|[A-Q]|[q-z]|[Q-Z]')
gra.edge('r7','r7','[a-z]|[A-Z]')
gra.edge('s42','r7','[a-z]|[A-Z]')

#node for start letter 'g'
gra.node('s43', 's43',shape='circle')

#edge for start letter 'g'
gra.edge('s0','s43','g|G')

#nodes for words starting with 'g'
gra.node('s44', 's44',shape='circle')
gra.node('s45', 's45',shape='circle')
gra.node('s46', 's46',shape='doublecircle')

#"goto" edges
gra.edge('s43','s44','o|O')
gra.edge('s44','s45','t|T')
gra.edge('s45','s46','o|O')

#reject edges for words starting with 'g'
gra.edge('s43','r8','[a-n]|[A-N||[p-z]|[P-Z]')
gra.edge('s44','r8','[a-s]|[A-S]|[u-z]|[U-Z]')
gra.edge('s45','r8','[a-n]|[A-N]|[p-z]|[P-Z]')
gra.edge('s46','r8','[a-z]|[A-Z]')
gra.edge('r8','r8','[a-z]|[A-Z]')

#node for start letter 'i'
gra.node('s47', 's47',shape='circle')

#edge for start letter 'i'
gra.edge('s0','s47','i|I')

#nodes for words starting with 'i'
gra.node('s48', 's48',shape='doublecircle')

# "in" and "if" edges
gra.edge('s47','s48','n|N|f|F')

#reject edges for words starting with 'i'
gra.edge('s47','r9','[a-e]|[A-E||[g-m]|[G-M]|[o-z]|[O-Z]')
gra.edge('s48','r9','[a-z]|[A-Z]')
gra.edge('r9','r9','[a-z]|[A-Z]')

#node for start letter 'l'
gra.node('s49', 's49',shape='circle')

#edge for start letter 'l'
gra.edge('s0','s49','l|L')

#nodes for words starting with 'l'
gra.node('s50', 's50',shape='circle')
gra.node('s51', 's51',shape='circle')
gra.node('s52', 's52',shape='circle')
gra.node('s53', 's53',shape='doublecircle')

# "label" edges
gra.edge('s49','s50','a|A')
gra.edge('s50','s51','b|B')
gra.edge('s51','s52','e|E')
gra.edge('s52','s53','l|L')

#reject edges for words starting with 'l'
gra.edge('s49','r10','[b-z]|[B-Z]')
gra.edge('s50','r10','a|A|[c-z]|[C-Z]')
gra.edge('s51','r10','[a-d]|[A-D]|[f-z]|[F-Z]')
gra.edge('s52','r10','[a-k]|[A-K]|[m-z]|[M-Z]')
gra.edge('s53','r10','[a-z]|[A-Z]')
gra.edge('r10','r10','[a-z]|[A-Z]')

#node for start letter 'm'
gra.node('s54', 's54',shape='circle')

#edge for start letter 'm'
gra.edge('s0','s54','m|M')

#nodes for words starting with 'm'
gra.node('s55', 's55',shape='circle')
gra.node('s56', 's56',shape='doublecircle')

# "mod" edges
gra.edge('s54','s55','o|O')
gra.edge('s55','s56','d|D')

#reject edges for words starting with 'm'
gra.edge('s54','r11','[a-n]|[A-N]|[p-z]|[P-Z]')
gra.edge('s55','r11','[a-c]|[A-C]|[e-z]|[E-Z]')
gra.edge('s56','r11','[a-z]|[A-Z]')
gra.edge('r11','r11','[a-z]|[A-Z]')

#node for start letter 'n'
gra.node('s57', 's57',shape='circle')

#edge for start letter 'n'
gra.edge('s0','s57','n|N')

#nodes for words starting with 'N'
gra.node('s58', 's58',shape='circle')
gra.node('s59', 's59',shape='circle')
gra.node('s60', 's60',shape='doublecircle')

# "nil" edges
gra.edge('s57','s58','i|I')
gra.edge('s58','s60','l|L')

# "not" edges
gra.edge('s57','s59','o|O')
gra.edge('s59','s60','t|T')

#reject edges for words starting with 'n'
gra.edge('s57','r12','[a-h]|[A-H]|[l-n]|[L-N]|[p-z]|[P-Z]')
gra.edge('s58','r12','[a-k]|[A-K]|[m-z]|[M-Z]')
gra.edge('s59','r12','[a-s]|[A-S]|[u-z]|[U-Z]')
gra.edge('s60','r12','[a-z]|[A-Z]')
gra.edge('r12','r12','[a-z]|[A-Z]')

#node for start letter 'o'
gra.node('s61', 's61',shape='circle')

#edge for start letter 'o'
gra.edge('s0','s61','o|O')

#nodes for words starting with 'o'
gra.node('s62', 's62',shape='doublecircle')

# "of" and "or" edges
gra.edge('s61','s62','f|F|r|R')

#reject edges for words starting with 'i'
gra.edge('s61','r13','[a-e]|[A-E||[g-q]|[G-Q]|[s-z]|[S-Z]')
gra.edge('s62','r13','[a-z]|[A-Z]')
gra.edge('r13','r13','[a-z]|[A-Z]')

#node for start letter 'p'
gra.node('s63', 's63',shape='circle')

#edge for start letter 'p'
gra.edge('s0','s63','p|P')

#nodes for words starting with 'p'
gra.node('s64', 's64',shape='circle')
gra.node('s65', 's65',shape='circle')
gra.node('s66', 's66',shape='circle')
gra.node('s67', 's67',shape='circle')
gra.node('s68', 's68',shape='circle')
gra.node('s69', 's69',shape='circle')
gra.node('s70', 's70',shape='circle')
gra.node('s71', 's71',shape='circle')
gra.node('s72', 's72',shape='circle')
gra.node('s73', 's73',shape='circle')
gra.node('s74', 's74',shape='circle')
gra.node('s75', 's75',shape='circle')
gra.node('s76', 's76',shape='circle')
gra.node('s77', 's77',shape='circle')
gra.node('s78', 's78',shape='doublecircle')

#"packed" edges
gra.edge('s63','s64','a|A')
gra.edge('s64','s65','c|C')
gra.edge('s65','s66','k|K')
gra.edge('s66','s67','e|E')
gra.edge('s67','s78','d|D')

#"procedure" edges
gra.edge('s63','s68','r|R')
gra.edge('s68','s69','o|O')
gra.edge('s69','s70','c|C')
gra.edge('s70','s71','e|E')
gra.edge('s71','s72','d|D')
gra.edge('s72','s73','u|U')
gra.edge('s73','s74','r|R')
gra.edge('s74','s78','e|E')

#"program" edges
gra.edge('s69','s75','g|G')
gra.edge('s75','s76','r|R')
gra.edge('s76','s77','a|A')
gra.edge('s77','s78','m|M')

#reject edges for words starting with 'p'
gra.edge('s63','r14','[b-q]|[b-Q|[s-z]|[S-Z]')
gra.edge('s64','r14','[a-b]|[A-B]|[d-z]|[D-Z]')
gra.edge('s65','r14','[a-j]|[A-J]|[l-z]|[L-Z]')
gra.edge('s66','r14','[a-d]|[A-D]|[f-z]|[F-Z]')
gra.edge('s67','r14','[a-c]|[A-C]|[e-z]|[E-Z]')
gra.edge('s68','r14','[a-n]|[A-N]|[p-z]|[P-Z]')
gra.edge('s69','r14','[a-b]|[A-B]|[d-f]|[D-F]|[h-z]|[H-Z]')
gra.edge('s70','r14','[a-d]|[A-D]|[f-z]|[F-Z]')
gra.edge('s71','r14','[a-c]|[A-C]|[e-z]|[E-Z]')
gra.edge('s72','r14','[a-t]|[A-T]|[v-z]|[V-Z]')
gra.edge('s73','r14','[a-q]|[A-Q]|[s-z]|[S-Z]')
gra.edge('s74','r14','[a-d]|[A-D]|[f-z]|[F-Z]')
gra.edge('s75','r14','[a-q]|[A-Q]|[s-z]|[S-Z]')
gra.edge('s76','r14','[b-z]|[B-Z]')
gra.edge('s77','r14','[a-l]|[A-L]|[n-z]|[N-Z]')
gra.edge('r14','r14','[a-z]|[A-Z]')
gra.edge('s78','r14','[a-z]|[A-Z]')

#node for start letter 'R'
gra.node('s79', 's79',shape='circle')

#edge for start letter 'R'
gra.edge('s0','s79','r|R')

#nodes for words starting with 'R'
gra.node('s80', 's80',shape='circle')
gra.node('s81', 's81',shape='circle')
gra.node('s82', 's82',shape='circle')
gra.node('s84', 's83',shape='circle')
gra.node('s85', 's85',shape='circle')
gra.node('s86', 's86',shape='circle')
gra.node('s87', 's87',shape='doublecircle')

#"Record" edges
gra.edge('s79','s80','e|E')
gra.edge('s80','s81','c|C')
gra.edge('s81','s82','o|O')
gra.edge('s82','s83','r|R')
gra.edge('s83','s87','d|D')

#"Repeat" edges
gra.edge('s80','s84','p|P')
gra.edge('s84','s85','e|E')
gra.edge('s85','s86','a|A')
gra.edge('s86','s87','t|T')

#reject edges for words starting with 'r'
gra.edge('s79','r15','[a-d]|[A-D|[a-d]|[F-Z]')
gra.edge('s80','r15','[a-b]|[A-B]|[d-o]|[D-O]|[q-z]|[Q-Z]')
gra.edge('s81','r15','[a-n]|[A-N]|[p-z]|[P-Z]')
gra.edge('s82','r15','[a-q]|[A-Q]|[s-z]|[S-Z]')
gra.edge('s83','r15','[a-c]|[A-C]|[e-z]|[E-Z]')
gra.edge('s84','r15','[a-d]|[A-D]|[f-z]|[F-Z]')
gra.edge('s85','r15','[b-z]|[B-Z]')
gra.edge('s86','r15','[a-s]|[A-S]|[u-z]|[U-Z]')
gra.edge('s87','r15','[a-z]|[A-Z]')
gra.edge('r15','r15','[a-z]|[A-Z]')

#node for start letter 'S'
gra.node('s88', 's88',shape='circle')

#edge for start letter 'S'
gra.edge('s0','s88','s|S')

#nodes for words starting with 'S'
gra.node('s89', 's89',shape='circle')
gra.node('s90', 's90',shape='doublecircle')

#"Set" edges
gra.edge('s88','s89','e|E')
gra.edge('s89','s90','t|T')

#reject edges for words starting with 'S'
gra.edge('s88','r16','[a-d]|[A-D|[f-z]|[F-Z]')
gra.edge('s89','r16','[a-s]|[A-S]|[u-z]|[U-Z]')
gra.edge('s90','r16','[a-z]|[A-Z]')
gra.edge('r16','r16','[a-z]|[A-Z]')

#node for start letter 'T'
gra.node('s91', 's91',shape='circle')

#edge for start letter 'T'
gra.edge('s0','s91','t|T')

#nodes for words starting with 'T'
gra.node('s92', 's92',shape='circle')
gra.node('s93', 's93',shape='circle')
gra.node('s94', 's94',shape='circle')
gra.node('s95', 's95',shape='circle')
gra.node('s96', 's96',shape='doublecircle')

#"Then" edges
gra.edge('s91','s92','h|H')
gra.edge('s92','s93','e|E')
gra.edge('s93','s96','n|N')

#"To" edges
gra.edge('s91','s96','o|O')

#"Type" edges
gra.edge('s91','s94','y|Y')
gra.edge('s94','s95','p|P')
gra.edge('s95','s96','e|E')

#reject edges for words starting with 'T'
gra.edge('s91','r17','[a-g]|[A-G|[i-n]|[I-N]|[p-x]|[P-X]|z|Z')
gra.edge('s92','r17','[a-d]|[A-D]|[f-z]|[F-Z]')
gra.edge('s93','r17','[a-m]|[A-M]|[p-z]|[P-Z]')
gra.edge('s94','r17','[a-o]|[A-O]|[q-z]|[Q-Z]')
gra.edge('s95','r17','[a-d]|[A-D]|[f-z]|[F-Z]')
gra.edge('s96','r17','[a-z]|[A-Z]')
gra.edge('r17','r17','[a-z]|[A-Z]')

#node for start letter 'U'
gra.node('s97', 's97',shape='circle')

#edge for start letter 'U'
gra.edge('s0','s97','u|U')

#nodes for words starting with 'U'
gra.node('s98', 's98',shape='circle')
gra.node('s99', 's99',shape='circle')
gra.node('s100', 's100',shape='circle')
gra.node('s101', 's101',shape='doublecircle')

#"Until" edges
gra.edge('s97','s98','n|N')
gra.edge('s98','s99','t|T')
gra.edge('s99','s100','i|I')
gra.edge('s100','s101','l|L')

#reject edges for words starting with 'U'
gra.edge('s97','r18','[a-m]|[A-M|[o-z]|[O-Z]')
gra.edge('s98','r18','[a-s]|[A-S]|[u-z]|[U-Z]')
gra.edge('s99','r18','[a-h]|[A-H]|[j-z]|[J-Z]')
gra.edge('s100','r18','[a-k]|[A-K]|[m-z]|[M-Z]')
gra.edge('s101','r18','[a-z]|[A-Z]')
gra.edge('r18','r18','[a-z]|[A-Z]')

#node for start letter 'V'
gra.node('s102', 's102',shape='circle')

#edge for start letter 'V'
gra.edge('s0','s102','v|V')

#nodes for words starting with 'V'
gra.node('s103', 's103',shape='circle')
gra.node('s104', 's104',shape='doublecircle')

#"Var" edges
gra.edge('s102','s103','a|A')
gra.edge('s103','s104','r|R')

#reject edges for words starting with 'V'
gra.edge('s102','r19','[b-z]|[B-Z]')
gra.edge('s103','r19','[a-q]|[A-Q]|[t-z]|[T-Z]')
gra.edge('s104','r19','[a-z]|[A-Z]')
gra.edge('r19','r19','[a-z]|[A-Z]')

#node for start letter 'W'
gra.node('s105', 's105',shape='circle')

#edge for start letter 'W'
gra.edge('s0','s105','w|W')

#nodes for words starting with 'W'
gra.node('s106', 's106',shape='circle')
gra.node('s107', 's107',shape='circle')
gra.node('s108', 's108',shape='circle')
gra.node('s109', 's109',shape='circle')
gra.node('s110', 's110',shape='circle')
gra.node('s111', 's111',shape='doublecircle')

#"While" edges
gra.edge('s105','s106','h|H')
gra.edge('s106','s107','i|I')
gra.edge('s107','s108','l|L')
gra.edge('s108','s111','e|E')

#"With" edges
gra.edge('s105','s109','i|I')
gra.edge('s109','s110','t|T')
gra.edge('s110','s111','h|H')

#reject edges for words starting with 'W'
gra.edge('s105','r20','[a-g]|[A-G]|[j-z]|[J-Z]')
gra.edge('s106','r20','[a-h]|[A-H]|[j-z]|[J-Z]')
gra.edge('s107','r20','[a-k]|[A-K]|[m-z]|[M-Z]')
gra.edge('s108','r20','[a-d]|[A-D]|[f-z]|[F-Z]')
gra.edge('s109','r20','[a-s]|[A-S]|[u-z]|[U-Z]')
gra.edge('s110','r20','[a-g]|[A-g]|[i-z]|[I-Z]')
gra.edge('s111','r20','[a-z]|[A-Z]')
gra.edge('r20','r20','[a-z]|[A-Z]')

#reject edges for initial node
gra.edge('s0','r21','h|H|j|J|k|K|q|Q|[x-z]|[X-Z]')

gra.render('DFA', format='pdf')
# Out:
# 'DFA.pdf'

# %%
gra

# %%
from graphviz import Digraph

gra = Digraph()
gra.node('s','',color='white')
gra.node('s0', 's0',shape='circle')
gra.node('r','r')
gra.edge('s','s0')
gra.edge('r','r','[1-9]|!|@|#|$|^|&|*|(|)|-|/|.|}|{|"|:|>|<|}|[a-z]|[A-Z]')
gra.node("s1","s1",shape='doublecircle')
gra.edge('s0','s1','[A-Z]|[a-z]')
gra.edge('s0','r','[1-9]|!|@|#|$|^|&|*|(|)|-|/|.|}|{|"|:|>|<|}')
gra.edge('s1','r','!|@|#|$|^|&|*|(|)|-|/|.|}|{|"|:|>|<|}')
gra.edge('s1','s1','[a-z]|[A-Z]|[1-9]||_')
gra

# %%
from graphviz import Digraph

gra = Digraph()

#initial state
gra.node('s','',color='white')
gra.node('s0', 's0',shape='circle')
gra.edge('s','s0')

gra.node('s1', 's1', shape = 'doublecircle')
gra.node('s2', 's2', shape = 'doublecircle')

gra.edge('s0','s1','+|-|=|*|/')
gra.edge('s0','s2','>|<')
gra.edge('s2','s1','=')

#reject
gra.node('r','reject')
gra.edge('s0','r','!|@|#|$|^|&|*|(|)|-|/|.|}|{|"|:|}')
gra.edge('s1','r','!|@|#|$|^|&|*|(|)|-|/|.|}|{|"|:|>|<|}|+|-|=|*|/')
gra.edge('s2','r','!|@|#|$|^|&|*|(|)|-|/|.|}|{|"|:|>|<|}|+|-|*|/')
gra.edge('r','r','!|@|#|$|^|&|*|(|)|-|/|.|}|{|"|:|>|<|}|+|-|=|*|/')

gra
